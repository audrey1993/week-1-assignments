# %%
import matplotlib as mpl
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
earthquake_df = pd.read_csv('file:///Users/audreynosenga/Desktop/all_month.csv')
earthquake_df.describe()
# Out:
#           latitude    longitude        depth          mag          nst  \
# count  8623.000000  8623.000000  8623.000000  8623.000000  6203.000000
# mean     37.054058  -108.285298    23.541292     1.537389    19.979204
# std      19.823248    70.392278    58.955886     1.343885    16.935117
# min     -65.196300  -179.971500    -3.470000    -1.380000     2.000000
# 25%      33.346417  -149.924350     4.220000     0.680000     8.000000
# 50%      37.813333  -118.924100     8.740000     1.270000    14.000000
# 75%      51.672000  -113.988583    15.965000     2.070000    26.000000
# max      86.633700   179.990100   641.480000     7.200000   202.000000
#
#                gap         dmin          rms  horizontalError   depthError  \
# count  7228.000000  5656.000000  8623.000000      6330.000000  8622.000000
# mean    123.820705     0.720915     0.280002         1.846943     3.646842
# std      67.717041     2.297009     0.293635         3.169963    51.498950
# ...

# %%
earthquake_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8623 entries, 0 to 8622
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             8623 non-null   object
#  1   latitude         8623 non-null   float64
#  2   longitude        8623 non-null   float64
#  3   depth            8623 non-null   float64
#  4   mag              8623 non-null   float64
#  5   magType          8623 non-null   object
#  6   nst              6203 non-null   float64
#  7   gap              7228 non-null   float64
#  8   dmin             5656 non-null   float64
#  9   rms              8623 non-null   float64
#  10  net              8623 non-null   object
#  11  id               8623 non-null   object
#  12  updated          8623 non-null   object
#  13  place            8623 non-null   object
#  14  type             8623 non-null   object
#  15  horizontalError  6330 non-null   float64
# ...

# %%
display(earthquake_df)
# Out:
#                           time   latitude   longitude      depth   mag  \
# 0     2022-06-13T02:23:50.618Z  64.810800 -150.968800  12.800000  1.00
# 1     2022-06-13T02:04:01.150Z  19.251499 -155.383163  30.870001  2.32
# 2     2022-06-13T02:03:17.812Z  64.737600 -149.067700  16.900000  0.50
# 3     2022-06-13T01:28:54.920Z  33.488833 -116.487500  16.310000  0.74
# 4     2022-06-13T01:26:51.840Z  17.987000  -66.979333   6.930000  1.81
# ...                        ...        ...         ...        ...   ...
# 8618  2022-05-14T02:53:06.460Z  35.538000 -117.420667   3.510000  1.08
# 8619  2022-05-14T02:37:24.170Z  36.783667 -121.521667   7.780000  0.90
# 8620  2022-05-14T02:33:33.510Z  38.780666 -122.765831   1.980000  0.36
# 8621  2022-05-14T02:32:38.610Z  35.642833 -118.322333   8.040000  1.15
# 8622  2022-05-14T02:31:22.670Z  33.859000 -116.589000  15.370000  0.79
#
#      magType   nst    gap      dmin   rms  ...                   updated  \
# ...
