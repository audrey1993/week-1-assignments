# %%
#import 
import random
#set function to roll dice on
def roll_dice():
    #roll_dice = random.randrange (1,7)
    #print('Player rolled dice')
#Dice minimum and maximum scores
    min = int(1)
    max = int(6)
    Count = int(0)

#roll_dice_again = str('yes')
#roll_dice_again2 = str('no')

start_game = str(input('Do you want to roll dice?'))

if start_game == str('yes'):
    roll_dice = int(input('enter first number'))
    roll_dice = int(input('enter second number'))
    roll_dice = int(input('enter third number'))
    roll_dice = int(input('enter third number'))
    role_dice = int(input('enter fourth number'))
    role_dice = int(input('enter ffifth number'))
    role_dice = int(input('enter) sixth number'))
else:
    print (str('Ok, Maybe we can play again next time when you are ready!!!'))

    
    
    
    
    
    
    #roll_dice = int()
        #sum = 0
        #for i in range
    #print(str("you have scored", total ))
    #if start_game != str('yes'):
        







#if start_game == str('yes'):
    #print(str('rolling dice again'))
#elif start_game !=str('yes'):
    #print(str(('Ok, Maybe we can play again next time when you are ready!!!')))

#return str('rolling dice')
    


    #print (str('rolling dice'))
        
    #if start_game != str('yes'):
    
    
    #roll_dice = int(input('enter a number'))
#if roll_dice == 2:
        #print('Sorry you lose!')
#elif roll_dice !=2:
        #roll_dice = int(input('enter a number'))









#while str('roll_dice again') == str('yes'):
        #roll_dice = int(input('Enter number to roll dice'))

        #for i in range(1,7):
